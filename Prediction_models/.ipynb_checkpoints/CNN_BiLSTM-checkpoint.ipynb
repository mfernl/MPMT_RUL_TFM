# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## CMAPSSData Preprocessing

# %%
#Eliminar sensores constantes
def eliminar_constantes(df, umbral_std=0.01):
    sensor_cols = [c for c in df.columns if c.startswith("s")]
    std = df[sensor_cols].std()
    constantes = std[std < umbral_std].index.tolist()
    print(f"Sensores eliminados por baja varianza: {constantes}")
    return df.drop(columns=constantes), constantes

#Calcular y añadir la etiqueta RUL
def add_rul_train(df, rul_max=125):
    """
    RUL real = ciclos restantes hasta el fallo.
    Se trunca a rul_max (cap lineal): permite que el modelo se centre en los ciclos 
    cercanos al fallo. No hay necesidad de predecir el fallo desde el inicio del trayecto.
    """
    max_ciclo = df.groupby("motor_id")["ciclo"].max().rename("ciclo_max")
    df = df.join(max_ciclo, on="motor_id")
    df["rul"] = (df["ciclo_max"] - df["ciclo"]).clip(upper=rul_max)
    df = df.drop(columns=["ciclo_max"])
    return df

def add_rul_test(df, rul_finales, rul_max=125):
    """
    En test, NASA proporciona cuántos ciclos quedaban al final
    del fragmento observado. Se suman los ciclos restantes y se calcula
    el RUL para cada ciclo de cada motor
    """
    rul_map = {
        motor_id + 1: rul
        for motor_id, rul in enumerate(rul_finales["rul_final"].values)
    }
    max_ciclo = df.groupby("motor_id")["ciclo"].max()
    
    def rul_para_motor(row):
        rul_final = rul_map[row["motor_id"]]
        ciclos_restantes = (max_ciclo[row["motor_id"]] - row["ciclo"]) + rul_final
        return min(ciclos_restantes, rul_max)
    
    df["rul"] = df.apply(rul_para_motor, axis=1)
    return df

def norm(train_df, test_df, feature_cols):
    """
    MinMaxScaler ajustado SOLO sobre train.
    Aplica la misma transformación a test sin re-ajustar.
    """
    scaler = MinMaxScaler(feature_range=(0, 1))
    
    train_df = train_df.copy()
    test_df = test_df.copy()
    
    train_df[feature_cols] = scaler.fit_transform(train_df[feature_cols])
    test_df[feature_cols] = scaler.transform(test_df[feature_cols]) 
    
    return train_df, test_df, scaler

def crear_ventanas(df, feature_cols, window_size=30):
    """
    Para cada motor, recorre sus ciclos con una ventana de tamaño window_size.
    Si el motor tiene menos ciclos que window_size, se rellena con padding
    al principio (ceros)
    
    Devuelve:
        X: (N, window_size, n_features)
        y: (N,)  — RUL en el último ciclo de cada ventana
    """
    X_list, y_list = [], []
    
    for motor_id, grupo in df.groupby("motor_id"):
        datos = grupo[feature_cols].values   # (ciclos, n_features)
        etiqueta = grupo["rul"].values           # (ciclos,)
        n_ciclos = len(datos)
        
        if n_ciclos < window_size:
            # Padding al principio con ceros
            pad = np.zeros((window_size - n_ciclos, datos.shape[1]))
            datos = np.vstack([pad, datos])
            etiqueta = np.concatenate([np.full(window_size - n_ciclos, etiqueta[0]), etiqueta])
            n_ciclos = window_size
        
        for i in range(n_ciclos - window_size + 1):
            X_list.append(datos[i : i + window_size])
            y_list.append(etiqueta[i + window_size - 1])   # RUL del último ciclo
    
    return np.array(X_list, dtype=np.float32), np.array(y_list, dtype=np.float32)

def crear_ventanas_test(df, feature_cols, window_size=30):
    """
    Se usa la última ventana de cada motor
    """
    X_list, y_list = [], []
    
    for motor_id, grupo in df.groupby("motor_id"):
        datos = grupo[feature_cols].values
        etiqueta = grupo["rul"].values
        n_ciclos = len(datos)
        
        if n_ciclos >= window_size:
            X_list.append(datos[-window_size:])
        else:
            pad = np.zeros((window_size - n_ciclos, datos.shape[1]))
            ventana = np.vstack([pad, datos])
            X_list.append(ventana)
        
        y_list.append(etiqueta[-1])
    
    return np.array(X_list, dtype=np.float32), np.array(y_list, dtype=np.float32)

# %%
def preparar_dataset(ruta_base="CMAPSSData", subset="FD001", window_size=30, rul_max=125):

    COLS = (
    ["motor_id", "ciclo"] +
    [f"op_{i}" for i in range(1, 4)] +          # 3 configuraciones operacionales
    [f"s{i}" for i in range(1, 22)]             # 21 sensores
    )
    
    train_data = pd.read_csv('../CMAPSSData/train_FD001.txt', sep=r"\s+", header=None, names=COLS)
    test_data = pd.read_csv('../CMAPSSData/test_FD001.txt',  sep=r"\s+", header=None, names=COLS)
    rul = pd.read_csv('../CMAPSSData/RUL_FD001.txt',   sep=r"\s+", header=None, names=["rul_final"])
    
    # Añadir etiquetas RUL
    train_df = add_rul_train(train_data.copy(), rul_max=rul_max)
    test_df  = add_rul_test(test_data.copy(), rul, rul_max=rul_max)

    # Eliminar sensores constantes (calculado sobre train)
    sensor_cols = [c for c in train_df.columns if c.startswith("s")]
    std = train_df[sensor_cols].std()
    constantes = std[std < 0.01].index.tolist()
    train_df = train_df.drop(columns=constantes)
    test_df  = test_df.drop(columns=constantes)

    # Columnas que entran al modelo (sensores + config. operacional)
    feature_cols = [c for c in train_df.columns
                    if c.startswith("s") or c.startswith("op")]

    # Normalizar
    train_df, test_df, scaler = norm(train_df, test_df, feature_cols)

    # Ventanas
    X_train_full, y_train_full = crear_ventanas(train_df, feature_cols, window_size)
    X_test,  y_test  = crear_ventanas_test(test_df, feature_cols, window_size)

    # Split validación desde train
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_full, y_train_full, test_size=0.15, random_state=42
    )

    print(f"X_train: {X_train.shape}  y_train: {y_train.shape}")
    print(f"X_val:   {X_val.shape}    y_val:   {y_val.shape}")
    print(f"X_test:  {X_test.shape}   y_test:  {y_test.shape}")
    print(f"Features usadas: {len(feature_cols)} — {feature_cols}")

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), scaler, feature_cols

# %%
# Ejemplo de uso:
(X_tr, y_tr), (X_val, y_val), (X_te, y_te), scaler, feats = preparar_dataset()
# model.fit(X_tr, y_tr, validation_data=(X_val, y_val), ...)
# Out:
# X_train: (15071, 30, 17)  y_train: (15071,)
# X_val:   (2660, 30, 17)    y_val:   (2660,)
# X_test:  (100, 30, 17)   y_test:  (100,)
# Features usadas: 17 — ['op_1', 'op_2', 'op_3', 's2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']

# %% [markdown]
# ## 1D_CNN

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input

# %%
#Construcción CNN reutilizable
def bloque_conv(x, filtros, kernel_size, dilation_rate=1, nombre=""):
    """
    Unidad básica: Conv1D → BatchNorm → ReLU → Dropout ligero.
    dilation_rate > 1 amplía el campo receptivo sin aumentar parámetros.
    """
    x = layers.Conv1D(
        filters      = filtros,
        kernel_size  = kernel_size,
        padding      = "same",          # conserva la longitud temporal
        dilation_rate= dilation_rate,
        use_bias     = False,           # BatchNorm tiene su propio bias
        name         = f"conv_{nombre}"
    )(x)
    x = layers.BatchNormalization(name=f"bn_{nombre}")(x)
    x = layers.Activation("relu", name=f"relu_{nombre}")(x)
    return x


def build_cnn_block(inp, filtros=64, nombre_base="cnn"):
    """
    Tres capas convolucionales con kernel sizes distintos (3, 5, 3)
    y la tercera con dilation=2 para capturar tendencias más largas.

    Entrada:  (batch, window_size, n_sensores)
    Salida:   (batch, window_size, filtros)  ← misma longitud temporal
    """
    # Capa 1 — patrones locales finos (3 ciclos)
    x = bloque_conv(inp, filtros, kernel_size=3, nombre=f"{nombre_base}_1")

    # Capa 2 — patrones medios (5 ciclos)
    x = bloque_conv(x,   filtros, kernel_size=5, nombre=f"{nombre_base}_2")

    # Capa 3 — patrones dilatados: campo receptivo = 5 ciclos con solo 3 pesos
    x = bloque_conv(x,   filtros, kernel_size=3,
                    dilation_rate=2, nombre=f"{nombre_base}_3")

    # Conexión residual: si el número de canales cambia, proyectar con Conv 1×1
    if inp.shape[-1] != filtros:
        shortcut = layers.Conv1D(filtros, 1, padding="same",
                                 use_bias=False, name=f"{nombre_base}_proj")(inp)
        shortcut = layers.BatchNormalization(name=f"{nombre_base}_bn_proj")(shortcut)
    else:
        shortcut = inp

    x = layers.Add(name=f"{nombre_base}_residual")([x, shortcut])
    x = layers.Activation("relu", name=f"{nombre_base}_out")(x)
    return x

# %%
def build_cnn_block(inp, filtros=64):
    """
    Versión sin residual — más fácil de leer, funciona bien para CMAPSS.
    La dimensión temporal se conserva gracias a padding='same'.
    NO hay Flatten porque la salida va al BiLSTM.
    """
    x = layers.Conv1D(filtros, kernel_size=3, padding="same", activation="relu")(inp)
    x = layers.BatchNormalization()(x)

    x = layers.Conv1D(filtros, kernel_size=5, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv1D(filtros, kernel_size=3, padding="same",
                      dilation_rate=2, activation="relu")(x)
    x = layers.BatchNormalization()(x)

    # Salida: (batch, window_size, filtros) — secuencia intacta para el BiLSTM
    return x

# %% [markdown]
# ## Capa de Atención

# %%
#Capa de atención
class BahdanauAttention(layers.Layer):
    def __init__(self, units=64, **kwargs):
        super().__init__(**kwargs)
        self.W = layers.Dense(units, use_bias=True)
        self.v = layers.Dense(1, use_bias=False)

    def call(self, h):
        score = self.v(tf.nn.tanh(self.W(h)))    # (batch, T, 1)
        weights = tf.nn.softmax(score, axis=1)      # (batch, T, 1)
        context = tf.reduce_sum(weights * h, axis=1) # (batch, dim)
        return context, weights

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"units": self.W.units})
        return cfg

# %% [markdown]
# ## Construcción del modelo

# %%
def build_model(window_size=30, n_features=19,
                cnn_filtros=64, lstm_units=64,
                attn_units=64, dropout=0.3):

    inp = Input(shape=(window_size, n_features), name="entrada")

    # 1. CNN — patrones espaciales entre sensores
    x = build_cnn_block(inp, filtros=cnn_filtros)
    # (batch, 30, 64)

    # 2. BiLSTM — dependencias temporales en ambas direcciones
    x = layers.Bidirectional(
            layers.LSTM(lstm_units, return_sequences=True), name="bilstm_1")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Bidirectional(
            layers.LSTM(lstm_units, return_sequences=True), name="bilstm_2")(x)
    x = layers.Dropout(dropout)(x)
    # (batch, 30, 128)  ← 128 porque Bidirectional concatena fwd + bwd

    # 3. Atención — pondera timesteps por relevancia
    context, attn_weights = BahdanauAttention(units=attn_units, name="atencion")(x)
    # context: (batch, 128)

    # 4. Top Model
    x = layers.Dense(128, activation="relu")(context)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(64, activation="relu")(x)
    rul = layers.Dense(1, name="rul")(x)

    model = Model(inputs=inp, outputs=rul, name="CNN_BiLSTM_Attn")
    return model


#model = build_model()
#model.summary()

# %%
# ── Pérdida asimétrica NASA ─────────────────────────────────────────────────
# Penaliza más predecir que queda MÁS vida de la que realmente queda
# (un fallo no anticipado es mucho más peligroso que una revisión anticipada)

def nasa_score_loss(y_true, y_pred):
    diff = y_pred - y_true
    score = tf.where(
        diff < 0,
        tf.exp(-diff / 13.0) - 1,   # predicción pesimista — penaliza suave
        tf.exp( diff / 10.0) - 1    # predicción optimista — penaliza fuerte
    )
    return tf.reduce_mean(score)

def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
# ── Preparar datos (del pipeline de preprocesamiento anterior) ──────────────

(X_train, y_train), (X_val, y_val), (X_test, y_test), scaler, feats = preparar_dataset()

# ── Compilar ────────────────────────────────────────────────────────────────

model = build_model(
    window_size = 30,
    n_features  = X_train.shape[2],   # se adapta automáticamente a los sensores útiles
    cnn_filtros = 64,
    lstm_units  = 64,
    attn_units  = 64,
    dropout     = 0.3
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor           = "val_loss",
        patience          = 20,
        restore_best_weights = True,
        verbose           = 1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor  = "val_loss",
        factor   = 0.5,
        patience = 8,
        min_lr   = 1e-6,
        verbose  = 1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath       = "best_model.keras",
        monitor        = "val_rmse",     # guardamos el mejor RMSE, no el mejor loss
        save_best_only = True,
        verbose        = 1
    ),
    tf.keras.callbacks.CSVLogger("historial_entrenamiento.csv")
]

model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss      = nasa_score_loss,
    metrics   = [rmse, "mae"]
)
# Out:
# X_train: (15071, 30, 17)  y_train: (15071,)
# X_val:   (2660, 30, 17)    y_val:   (2660,)
# X_test:  (100, 30, 17)   y_test:  (100,)
# Features usadas: 17 — ['op_1', 'op_2', 'op_3', 's2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']
# WARNING:tensorflow:From C:\Users\marco\Desktop\Marco\TFM\venv\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
historial = model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs          = 150,
    batch_size      = 256,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 14s 119ms/step - loss: 1102.1691 - mae: 46.7284 - rmse: 66.8957 - val_loss: 27.6845 - val_mae: 27.5358 - val_rmse: 50.7513
# Epoch 2/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 13.6717 - mae: 23.7075 - rmse: 53.2077 - val_loss: 62.6445 - val_mae: 31.4402 - val_rmse: 43.4719
# Epoch 3/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - loss: 10.5841 - mae: 20.9880 - rmse: 52.8873 - val_loss: 115.1376 - val_mae: 32.8533 - val_rmse: 43.9620
# Epoch 4/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - loss: 9.5372 - mae: 19.7776 - rmse: 53.6705 - val_loss: 53.7359 - val_mae: 28.4292 - val_rmse: 46.3012
# Epoch 5/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - loss: 8.9219 - mae: 19.0884 - rmse: 54.0960 - val_loss: 25.7478 - val_mae: 24.2828 - val_rmse: 48.4957
# Epoch 6/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - loss: 7.4714 - mae: 17.8639 - rmse: 54.5964 - val_loss: 32.5555 - val_mae: 23.0177 - val_rmse: 50.7377
# Epoch 7/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 6.6562 - mae: 16.7837 - rmse: 54.9800 - val_loss: 17.3499 - val_mae: 21.3677 - val_rmse: 50.3093
# Epoch 8/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 6.2969 - mae: 16.3041 - rmse: 54.9773 - val_loss: 27.9670 - val_mae: 21.4452 - val_rmse: 51.6964
# Epoch 9/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 4.9119 - mae: 14.7857 - rmse: 55.5038 - val_loss: 12.1720 - val_mae: 18.4842 - val_rmse: 51.4404
# Epoch 10/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 4.1871 - mae: 13.5430 - rmse: 56.1333 - val_loss: 7.8279 - val_mae: 15.2678 - val_rmse: 54.0695
# Epoch 11/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 3.6162 - mae: 12.6493 - rmse: 56.4918 - val_loss: 14.0344 - val_mae: 19.2733 - val_rmse: 57.1002
# Epoch 12/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 2.8618 - mae: 11.4380 - rmse: 57.1608 - val_loss: 8.4164 - val_mae: 15.1275 - val_rmse: 53.7103
# Epoch 13/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 2.6006 - mae: 10.9775 - rmse: 57.2108 - val_loss: 4.1069 - val_mae: 13.3591 - val_rmse: 60.1882
# Epoch 14/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 2.1001 - mae: 9.9194 - rmse: 57.8097 - val_loss: 3.6883 - val_mae: 13.2489 - val_rmse: 59.6970
# Epoch 15/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 2.0575 - mae: 9.7625 - rmse: 57.9592 - val_loss: 3.4810 - val_mae: 14.2485 - val_rmse: 57.8580
# Epoch 16/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.8390 - mae: 9.2844 - rmse: 58.0376 - val_loss: 2.4824 - val_mae: 8.6672 - val_rmse: 58.9694
# Epoch 17/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 1.6385 - mae: 8.7834 - rmse: 58.3500 - val_loss: 1.9020 - val_mae: 10.6026 - val_rmse: 59.6673
# Epoch 18/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 1.7527 - mae: 9.0488 - rmse: 58.3085 - val_loss: 2.2514 - val_mae: 9.4742 - val_rmse: 55.0311
# Epoch 19/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 1.5752 - mae: 8.6549 - rmse: 58.4290 - val_loss: 1.0006 - val_mae: 6.8292 - val_rmse: 59.1729
# Epoch 20/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 1.3676 - mae: 8.0019 - rmse: 58.5838 - val_loss: 0.8744 - val_mae: 5.9458 - val_rmse: 58.8769
# Epoch 21/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 1.3242 - mae: 7.8508 - rmse: 58.5369 - val_loss: 1.0977 - val_mae: 6.3457 - val_rmse: 57.8571
# Epoch 22/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 1.3406 - mae: 7.8852 - rmse: 58.6626 - val_loss: 0.6953 - val_mae: 5.7150 - val_rmse: 57.5306
# Epoch 23/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 1.2384 - mae: 7.6001 - rmse: 58.7085 - val_loss: 0.6829 - val_mae: 5.5553 - val_rmse: 57.2792
# Epoch 24/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 1.3270 - mae: 7.8246 - rmse: 58.6530 - val_loss: 1.1152 - val_mae: 7.7332 - val_rmse: 58.4642
# Epoch 25/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 1.1946 - mae: 7.3601 - rmse: 58.7749 - val_loss: 0.6295 - val_mae: 5.2940 - val_rmse: 58.1939
# Epoch 26/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 1.3146 - mae: 7.7604 - rmse: 58.6745 - val_loss: 1.2860 - val_mae: 6.5974 - val_rmse: 57.1433
# Epoch 27/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 1.2271 - mae: 7.4976 - rmse: 58.6602 - val_loss: 0.8560 - val_mae: 6.5712 - val_rmse: 58.1302
# Epoch 28/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.1894 - mae: 7.3839 - rmse: 58.7933 - val_loss: 0.6931 - val_mae: 5.7216 - val_rmse: 57.0428
# Epoch 29/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 1.0789 - mae: 6.9342 - rmse: 58.8094 - val_loss: 0.8782 - val_mae: 6.6385 - val_rmse: 59.2546
# Epoch 30/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 1.1973 - mae: 7.4176 - rmse: 58.8031 - val_loss: 1.7433 - val_mae: 7.8867 - val_rmse: 56.6312
# Epoch 31/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 1.0916 - mae: 7.0227 - rmse: 58.7948 - val_loss: 0.5346 - val_mae: 4.6550 - val_rmse: 59.5679
# Epoch 32/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 1.0912 - mae: 6.9774 - rmse: 58.8145 - val_loss: 0.8029 - val_mae: 6.6161 - val_rmse: 58.9576
# Epoch 33/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.0963 - mae: 7.0089 - rmse: 58.8272 - val_loss: 0.5632 - val_mae: 4.5434 - val_rmse: 59.6056
# Epoch 34/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 1.0939 - mae: 6.9968 - rmse: 58.8301 - val_loss: 1.7528 - val_mae: 9.2301 - val_rmse: 61.2228
# Epoch 35/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 1.0182 - mae: 6.6967 - rmse: 58.8182 - val_loss: 0.4836 - val_mae: 4.3711 - val_rmse: 58.1832
# Epoch 36/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - loss: 1.0365 - mae: 6.7569 - rmse: 58.8003 - val_loss: 0.5147 - val_mae: 4.2301 - val_rmse: 57.4178
# Epoch 37/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 1.0146 - mae: 6.6507 - rmse: 58.8433 - val_loss: 0.5334 - val_mae: 4.6428 - val_rmse: 59.8126
# Epoch 38/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.0580 - mae: 6.8956 - rmse: 58.8665 - val_loss: 0.5930 - val_mae: 5.3674 - val_rmse: 58.3103
# Epoch 39/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 1.0075 - mae: 6.6801 - rmse: 58.8733 - val_loss: 0.4089 - val_mae: 3.8294 - val_rmse: 58.6108
# Epoch 40/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.9802 - mae: 6.5426 - rmse: 58.8199 - val_loss: 2.1177 - val_mae: 8.2869 - val_rmse: 56.3275
# Epoch 41/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.9866 - mae: 6.5002 - rmse: 58.8468 - val_loss: 0.4387 - val_mae: 4.1249 - val_rmse: 57.9908
# Epoch 42/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 1.0074 - mae: 6.6377 - rmse: 58.8070 - val_loss: 0.9165 - val_mae: 5.7495 - val_rmse: 56.0333
# Epoch 43/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.0159 - mae: 6.6772 - rmse: 58.8675 - val_loss: 0.6197 - val_mae: 4.9888 - val_rmse: 56.6968
# Epoch 44/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.9477 - mae: 6.3929 - rmse: 58.8295 - val_loss: 1.0000 - val_mae: 7.1972 - val_rmse: 55.9892
# Epoch 45/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - loss: 0.9356 - mae: 6.3589 - rmse: 58.8883 - val_loss: 0.7705 - val_mae: 5.3527 - val_rmse: 56.4277
# Epoch 46/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 1.0392 - mae: 6.7847 - rmse: 58.7314 - val_loss: 0.6576 - val_mae: 5.3459 - val_rmse: 56.7918
# Epoch 47/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 1.0451 - mae: 6.7934 - rmse: 58.8017 - val_loss: 0.4597 - val_mae: 3.9583 - val_rmse: 58.6103
# Epoch 48/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 0.9276 - mae: 6.2780 - rmse: 58.8714 - val_loss: 0.5741 - val_mae: 5.2099 - val_rmse: 58.8565
# Epoch 49/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.9204 - mae: 6.2549 - rmse: 58.8345 - val_loss: 1.3333 - val_mae: 9.4884 - val_rmse: 58.1367
# Epoch 50/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.9704 - mae: 6.4541 - rmse: 58.8341 - val_loss: 0.9709 - val_mae: 6.6350 - val_rmse: 60.8416
# Epoch 51/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.9947 - mae: 6.5719 - rmse: 58.7412 - val_loss: 0.8291 - val_mae: 6.6441 - val_rmse: 60.3309
# Epoch 52/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.9379 - mae: 6.4067 - rmse: 58.9124 - val_loss: 0.6806 - val_mae: 5.4354 - val_rmse: 59.3496
# Epoch 53/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.9015 - mae: 6.1443 - rmse: 58.8147 - val_loss: 0.9300 - val_mae: 6.8908 - val_rmse: 59.8299
# Epoch 54/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8677 - mae: 6.0147 - rmse: 58.8256 - val_loss: 0.5540 - val_mae: 3.9986 - val_rmse: 57.9242
# Epoch 55/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.9084 - mae: 6.2315 - rmse: 58.8758 - val_loss: 0.4984 - val_mae: 3.9050 - val_rmse: 57.1864
# Epoch 56/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.8684 - mae: 5.9961 - rmse: 58.7843 - val_loss: 0.4326 - val_mae: 3.3350 - val_rmse: 58.2728
# Epoch 57/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8920 - mae: 6.1367 - rmse: 58.8435 - val_loss: 0.6123 - val_mae: 5.6190 - val_rmse: 59.5693
# Epoch 58/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8733 - mae: 6.0730 - rmse: 58.8849 - val_loss: 0.5892 - val_mae: 5.5420 - val_rmse: 59.1811
# Epoch 59/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.9116 - mae: 6.2391 - rmse: 58.8382 - val_loss: 0.7134 - val_mae: 4.7399 - val_rmse: 56.9426
# Epoch 60/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8690 - mae: 6.0388 - rmse: 58.8400 - val_loss: 0.6831 - val_mae: 4.6627 - val_rmse: 57.0368
# Epoch 61/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8614 - mae: 6.0120 - rmse: 58.8603 - val_loss: 0.3092 - val_mae: 3.1087 - val_rmse: 58.5024
# Epoch 62/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8464 - mae: 5.8766 - rmse: 58.8019 - val_loss: 0.5215 - val_mae: 4.8190 - val_rmse: 59.5170
# Epoch 63/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8542 - mae: 5.9824 - rmse: 58.8621 - val_loss: 0.3784 - val_mae: 3.6447 - val_rmse: 57.5394
# Epoch 64/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8449 - mae: 5.8953 - rmse: 58.8865 - val_loss: 0.6478 - val_mae: 4.4839 - val_rmse: 56.9492
# Epoch 65/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8777 - mae: 6.0872 - rmse: 58.8057 - val_loss: 0.5177 - val_mae: 4.4602 - val_rmse: 60.0968
# Epoch 66/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8736 - mae: 6.0770 - rmse: 58.8622 - val_loss: 1.0186 - val_mae: 7.6829 - val_rmse: 58.8755
# Epoch 67/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8696 - mae: 6.0177 - rmse: 58.8811 - val_loss: 0.7743 - val_mae: 5.6115 - val_rmse: 56.1552
# Epoch 68/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8448 - mae: 5.9046 - rmse: 58.8222 - val_loss: 0.5616 - val_mae: 5.0204 - val_rmse: 58.9499
# Epoch 69/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8664 - mae: 5.9993 - rmse: 58.8708 - val_loss: 0.3117 - val_mae: 2.8745 - val_rmse: 57.8925
# Epoch 70/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8316 - mae: 5.8474 - rmse: 58.7785 - val_loss: 0.8517 - val_mae: 7.0988 - val_rmse: 59.5813
# Epoch 71/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8254 - mae: 5.8384 - rmse: 58.8837 - val_loss: 2.5289 - val_mae: 9.0358 - val_rmse: 57.2693
# Epoch 72/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8705 - mae: 6.0407 - rmse: 58.8289 - val_loss: 0.4511 - val_mae: 4.3865 - val_rmse: 59.5258
# Epoch 73/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.8308 - mae: 5.8016 - rmse: 58.8523 - val_loss: 0.5814 - val_mae: 5.3275 - val_rmse: 57.9973
# Epoch 74/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8322 - mae: 5.8348 - rmse: 58.8403 - val_loss: 0.8347 - val_mae: 6.7178 - val_rmse: 60.2170
# Epoch 75/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8249 - mae: 5.8175 - rmse: 58.8379 - val_loss: 1.0687 - val_mae: 7.9847 - val_rmse: 59.8323
# Epoch 76/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8257 - mae: 5.8410 - rmse: 58.7944 - val_loss: 0.3296 - val_mae: 3.0329 - val_rmse: 57.6582
# Epoch 77/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8064 - mae: 5.7664 - rmse: 58.8855 - val_loss: 0.4634 - val_mae: 4.1924 - val_rmse: 57.2441
# Epoch 78/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8243 - mae: 5.8328 - rmse: 58.8619 - val_loss: 0.3199 - val_mae: 3.2020 - val_rmse: 59.1664
# Epoch 79/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8044 - mae: 5.7286 - rmse: 58.8079 - val_loss: 0.3891 - val_mae: 3.8705 - val_rmse: 59.0501
# Epoch 80/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8064 - mae: 5.7408 - rmse: 58.9039 - val_loss: 1.5423 - val_mae: 6.7839 - val_rmse: 57.0110
# Epoch 81/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.7840 - mae: 5.6225 - rmse: 58.7987 - val_loss: 0.4184 - val_mae: 4.0742 - val_rmse: 59.0348
# Epoch 82/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8135 - mae: 5.7378 - rmse: 58.8587 - val_loss: 0.6702 - val_mae: 5.9583 - val_rmse: 58.9633
# Epoch 83/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.8044 - mae: 5.7236 - rmse: 58.8135 - val_loss: 0.3672 - val_mae: 3.1517 - val_rmse: 58.7216
# Epoch 84/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7860 - mae: 5.6478 - rmse: 58.8544 - val_loss: 0.3895 - val_mae: 2.9564 - val_rmse: 58.3924
# Epoch 85/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.8078 - mae: 5.7491 - rmse: 58.8098 - val_loss: 0.3788 - val_mae: 3.4881 - val_rmse: 57.7148
# Epoch 86/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 0.7766 - mae: 5.5260 - rmse: 58.8455 - val_loss: 0.3203 - val_mae: 2.8852 - val_rmse: 58.0436
# Epoch 87/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.7738 - mae: 5.5872 - rmse: 58.8175 - val_loss: 0.4681 - val_mae: 3.5615 - val_rmse: 57.4537
# Epoch 88/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.7671 - mae: 5.4806 - rmse: 58.8109 - val_loss: 1.1895 - val_mae: 8.0395 - val_rmse: 57.7392
# Epoch 89/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - loss: 0.7792 - mae: 5.5686 - rmse: 58.8261 - val_loss: 0.6385 - val_mae: 4.4238 - val_rmse: 57.1374
# Epoch 90/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.8254 - mae: 5.8075 - rmse: 58.8932 - val_loss: 0.4538 - val_mae: 4.2976 - val_rmse: 57.5921
# Epoch 91/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.9610 - mae: 6.3598 - rmse: 58.7306 - val_loss: 1.7699 - val_mae: 9.6642 - val_rmse: 57.9115
# Epoch 92/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.8208 - mae: 5.7997 - rmse: 58.8673 - val_loss: 0.3594 - val_mae: 3.1807 - val_rmse: 58.1327
# Epoch 93/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.7574 - mae: 5.4505 - rmse: 58.8109 - val_loss: 0.6462 - val_mae: 5.5512 - val_rmse: 58.3562
# Epoch 94/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7587 - mae: 5.4955 - rmse: 58.8168 - val_loss: 0.3204 - val_mae: 3.3662 - val_rmse: 58.9584
# Epoch 95/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.7709 - mae: 5.5193 - rmse: 58.8332 - val_loss: 0.2604 - val_mae: 2.3104 - val_rmse: 58.6940
# Epoch 96/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7642 - mae: 5.4781 - rmse: 58.8334 - val_loss: 0.5393 - val_mae: 5.1288 - val_rmse: 58.4135
# Epoch 97/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.7646 - mae: 5.5260 - rmse: 58.8660 - val_loss: 0.2937 - val_mae: 2.9493 - val_rmse: 58.7428
# Epoch 98/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7746 - mae: 5.5655 - rmse: 58.8352 - val_loss: 0.3178 - val_mae: 3.1668 - val_rmse: 58.0059
# Epoch 99/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7395 - mae: 5.3998 - rmse: 58.8181 - val_loss: 0.3543 - val_mae: 3.3834 - val_rmse: 58.6715
# Epoch 100/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7305 - mae: 5.3286 - rmse: 58.8878 - val_loss: 0.3198 - val_mae: 3.2064 - val_rmse: 57.7158
# Epoch 101/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.7456 - mae: 5.4078 - rmse: 58.8340 - val_loss: 0.3397 - val_mae: 3.4408 - val_rmse: 58.1606
# Epoch 102/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7247 - mae: 5.3197 - rmse: 58.8263 - val_loss: 0.3716 - val_mae: 3.0557 - val_rmse: 57.7774
# Epoch 103/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7418 - mae: 5.3966 - rmse: 58.8633 - val_loss: 0.3734 - val_mae: 3.0654 - val_rmse: 57.9852
# Epoch 104/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.7336 - mae: 5.3615 - rmse: 58.8368 - val_loss: 0.7635 - val_mae: 5.1012 - val_rmse: 56.2719
# Epoch 105/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7505 - mae: 5.4196 - rmse: 58.7422 - val_loss: 0.4873 - val_mae: 3.7885 - val_rmse: 59.0192
# Epoch 106/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7257 - mae: 5.3142 - rmse: 58.8511 - val_loss: 0.7117 - val_mae: 6.3126 - val_rmse: 58.5459
# Epoch 107/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7287 - mae: 5.3327 - rmse: 58.7676 - val_loss: 0.5401 - val_mae: 4.7672 - val_rmse: 57.3984
# Epoch 108/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7331 - mae: 5.3084 - rmse: 58.8469 - val_loss: 0.4973 - val_mae: 4.9322 - val_rmse: 59.1295
# Epoch 109/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.7371 - mae: 5.3879 - rmse: 58.8560 - val_loss: 2.0046 - val_mae: 9.7012 - val_rmse: 58.9555
# Epoch 110/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7140 - mae: 5.2348 - rmse: 58.8172 - val_loss: 0.3524 - val_mae: 3.6365 - val_rmse: 58.5305
# Epoch 111/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6926 - mae: 5.1145 - rmse: 58.8319 - val_loss: 0.3356 - val_mae: 3.3695 - val_rmse: 57.7091
# Epoch 112/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.7286 - mae: 5.3340 - rmse: 58.7788 - val_loss: 0.2724 - val_mae: 2.8301 - val_rmse: 58.3739
# Epoch 113/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6996 - mae: 5.1752 - rmse: 58.8121 - val_loss: 0.7345 - val_mae: 4.6923 - val_rmse: 56.6812
# Epoch 114/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.6951 - mae: 5.1884 - rmse: 58.8601 - val_loss: 1.1267 - val_mae: 5.6800 - val_rmse: 56.1196
# Epoch 115/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7018 - mae: 5.1688 - rmse: 58.7559 - val_loss: 0.4599 - val_mae: 4.5374 - val_rmse: 58.1643
# Epoch 116/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7025 - mae: 5.1856 - rmse: 58.8568 - val_loss: 0.3204 - val_mae: 3.2319 - val_rmse: 58.1211
# Epoch 117/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7267 - mae: 5.3170 - rmse: 58.8453 - val_loss: 0.7576 - val_mae: 5.2069 - val_rmse: 57.7471
# Epoch 118/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7163 - mae: 5.2373 - rmse: 58.8169 - val_loss: 0.6754 - val_mae: 5.9192 - val_rmse: 57.8000
# Epoch 119/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7062 - mae: 5.1685 - rmse: 58.8345 - val_loss: 0.3575 - val_mae: 3.3512 - val_rmse: 58.2190
# Epoch 120/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.7017 - mae: 5.1692 - rmse: 58.8067 - val_loss: 0.3793 - val_mae: 3.7026 - val_rmse: 58.1279
# Epoch 121/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7025 - mae: 5.1736 - rmse: 58.8376 - val_loss: 1.0196 - val_mae: 8.0493 - val_rmse: 59.4107
# Epoch 122/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6942 - mae: 5.1258 - rmse: 58.8354 - val_loss: 0.4021 - val_mae: 3.7574 - val_rmse: 57.2770
# Epoch 123/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6888 - mae: 5.1338 - rmse: 58.8131 - val_loss: 0.2559 - val_mae: 2.6248 - val_rmse: 58.2311
# Epoch 124/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.6728 - mae: 4.9970 - rmse: 58.8256 - val_loss: 0.4515 - val_mae: 4.4450 - val_rmse: 58.5593
# Epoch 125/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6828 - mae: 5.0608 - rmse: 58.8444 - val_loss: 0.3839 - val_mae: 3.9145 - val_rmse: 57.8291
# Epoch 126/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6842 - mae: 5.1161 - rmse: 58.7917 - val_loss: 0.2510 - val_mae: 2.5760 - val_rmse: 58.5892
# Epoch 127/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.6745 - mae: 5.0249 - rmse: 58.8188 - val_loss: 0.6932 - val_mae: 5.9622 - val_rmse: 58.5211
# Epoch 128/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.6769 - mae: 5.0431 - rmse: 58.8047 - val_loss: 0.3815 - val_mae: 3.8686 - val_rmse: 58.1571
# Epoch 129/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.6885 - mae: 5.1190 - rmse: 58.8250 - val_loss: 0.4949 - val_mae: 3.9867 - val_rmse: 57.2426
# Epoch 130/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.6771 - mae: 5.0610 - rmse: 58.7790 - val_loss: 0.3483 - val_mae: 3.0430 - val_rmse: 58.5256
# Epoch 131/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - loss: 0.6697 - mae: 4.9997 - rmse: 58.7739 - val_loss: 1.6209 - val_mae: 9.2843 - val_rmse: 59.6408
# Epoch 132/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6840 - mae: 5.0547 - rmse: 58.7733 - val_loss: 0.4521 - val_mae: 4.5049 - val_rmse: 58.8088
# Epoch 133/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.6854 - mae: 5.0597 - rmse: 58.8476 - val_loss: 0.2440 - val_mae: 2.3231 - val_rmse: 58.4404
# Epoch 134/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.6733 - mae: 5.0045 - rmse: 58.7960 - val_loss: 0.3548 - val_mae: 3.1660 - val_rmse: 58.4505
# Epoch 135/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.6755 - mae: 5.0254 - rmse: 58.8017 - val_loss: 1.4494 - val_mae: 8.6493 - val_rmse: 61.0841
# Epoch 136/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.6701 - mae: 5.0065 - rmse: 58.8504 - val_loss: 0.2980 - val_mae: 3.0816 - val_rmse: 58.4813
# Epoch 137/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.6691 - mae: 5.0004 - rmse: 58.7940 - val_loss: 0.3074 - val_mae: 2.8775 - val_rmse: 57.6721
# Epoch 138/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.6623 - mae: 4.9405 - rmse: 58.7987 - val_loss: 0.3444 - val_mae: 3.4826 - val_rmse: 59.1625
# Epoch 139/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.6610 - mae: 4.9752 - rmse: 58.8143 - val_loss: 0.2479 - val_mae: 2.3635 - val_rmse: 58.3935
# Epoch 140/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.6673 - mae: 4.9597 - rmse: 58.7949 - val_loss: 0.3366 - val_mae: 3.5505 - val_rmse: 58.6985
# Epoch 141/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 0.6667 - mae: 4.9930 - rmse: 58.8156 - val_loss: 0.3738 - val_mae: 3.6967 - val_rmse: 57.4885
# Epoch 142/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 0.6718 - mae: 5.0150 - rmse: 58.7858 - val_loss: 0.4048 - val_mae: 4.2251 - val_rmse: 58.6259
# Epoch 143/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 0.6537 - mae: 4.8967 - rmse: 58.7958 - val_loss: 0.2661 - val_mae: 2.8094 - val_rmse: 58.0608
# Epoch 144/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.6493 - mae: 4.8885 - rmse: 58.8352 - val_loss: 0.3566 - val_mae: 3.6026 - val_rmse: 57.7633
# Epoch 145/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.6586 - mae: 4.9376 - rmse: 58.8060 - val_loss: 0.3881 - val_mae: 3.9710 - val_rmse: 57.6212
# Epoch 146/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.6804 - mae: 5.0339 - rmse: 58.7794 - val_loss: 3.4647 - val_mae: 12.7286 - val_rmse: 54.9349
# Epoch 147/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.7465 - mae: 5.3690 - rmse: 58.7501 - val_loss: 11.3377 - val_mae: 17.5818 - val_rmse: 57.5509
# Epoch 148/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.7596 - mae: 5.4175 - rmse: 58.7672 - val_loss: 1.8873 - val_mae: 8.6418 - val_rmse: 57.2242
# Epoch 149/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.6815 - mae: 5.0484 - rmse: 58.7542 - val_loss: 11.2817 - val_mae: 16.6003 - val_rmse: 59.7190
# Epoch 150/150
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - loss: 0.7021 - mae: 5.1649 - rmse: 58.7919 - val_loss: 1.1987 - val_mae: 6.5285 - val_rmse: 56.2879
